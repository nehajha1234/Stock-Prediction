# %% [markdown]
# # DATA SCIENCE INTERNSHIP - BHARAT INTERN

# %% [markdown]
# ## INTERN NAME : NEHA JHA

# %% [markdown]
# ## TASK 1 : STOCK PREDICTION

# %% [markdown]
# ### Take stockprice of any company you want and predicts its price by using LSTM. Use only Jupyter notebook code

# %% [markdown]
# # Purpose

# %% [markdown]
# In this Colab, we will use a keras Long Short-Term Memory (LSTM) model to predict the stock price of Netflix
#
# Here are some imports we need to make:numpy for scientific computation, matplotlib for graphing, and pandas for manipulating data

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout

import warnings
warnings.filterwarnings("ignore")

# %%
# loading the data

df= pd.read_csv('netflix.csv')

# %%
# Set colors

class color:    
    GREEN, RED = '\033[92m', '\033[91m'
    BOLD, UNDERLINE, END = '\033[1m', '\033[4m', '\033[0m'
    GREEN_BOLD = GREEN + BOLD
    RED_BOLD = RED + BOLD
    GREEN_BOLD_UND = GREEN_BOLD + UNDERLINE   
    
rb, gb,  = color.RED_BOLD, color.GREEN_BOLD
gbu, end = color.GREEN_BOLD_UND, color.END

# %%
df.shape
# Out:
# (4881, 7)

# %%
df.head()
# Out:
#          Date      High       Low      Open     Close       Volume  Adj Close
# 0  2002-05-23  1.242857  1.145714  1.156429  1.196429  104790000.0   1.196429
# 1  2002-05-24  1.225000  1.197143  1.214286  1.210000   11104800.0   1.210000
# 2  2002-05-28  1.232143  1.157143  1.213571  1.157143    6609400.0   1.157143
# 3  2002-05-29  1.164286  1.085714  1.164286  1.103571    6757800.0   1.103571
# 4  2002-05-30  1.107857  1.071429  1.107857  1.071429   10154200.0   1.071429

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4881 entries, 0 to 4880
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4881 non-null   object
#  1   High       4881 non-null   float64
#  2   Low        4881 non-null   float64
#  3   Open       4881 non-null   float64
#  4   Close      4881 non-null   float64
#  5   Volume     4881 non-null   float64
#  6   Adj Close  4881 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 267.1+ KB

# %%
# Convert the type of "Date" column into date-time

df["Date"] = pd.to_datetime(df["Date"])
print (df.dtypes)
# Out:
# Date         datetime64[ns]
# High                float64
# Low                 float64
# Open                float64
# Close               float64
# Volume              float64
# Adj Close           float64
# dtype: object

# %%
# Add the "Year", 'Month' and "Day" columns
df["Year"] = df["Date"].apply(lambda x : str(x)[:4])
df["Month"] = df["Date"].apply(lambda x : str(x)[5:7])
df["Day"] = df["Date"].apply(lambda x : str(x)[8:10])

df.head()
# Out:
#         Date      High       Low      Open     Close       Volume  Adj Close  \
# 0 2002-05-23  1.242857  1.145714  1.156429  1.196429  104790000.0   1.196429
# 1 2002-05-24  1.225000  1.197143  1.214286  1.210000   11104800.0   1.210000
# 2 2002-05-28  1.232143  1.157143  1.213571  1.157143    6609400.0   1.157143
# 3 2002-05-29  1.164286  1.085714  1.164286  1.103571    6757800.0   1.103571
# 4 2002-05-30  1.107857  1.071429  1.107857  1.071429   10154200.0   1.071429
#
#    Year Month Day
# 0  2002    05  23
# 1  2002    05  24
# 2  2002    05  28
# 3  2002    05  29
# 4  2002    05  30

# %% [markdown]
# ## Feature Extraction

# %%
# Print the number of trading days
print(f'{rb}Total number of trading days: {end}{gbu}{df.shape[0]}{end}')
print(f'{rb}Total number of fields: {end}{gbu}{df.shape[1]}{end}')
print('\n')
# Check the Null and NA values
print(f'{rb}Null values: {end}{gbu}{df.isnull().values.sum()}{end}')
print(f'{rb}NA values: {end}{gbu}{df.isna().values.any()}{end}')
# Out:
# Total number of trading days: 4881
# Total number of fields: 10
#
#
# Null values: 0
# NA values: False

# %%
# Create a new dataframe with only the Open column and convert it into a NumPy array
df = df['Open'].values

# Reshape the data
df = df.reshape(-1, 1)

# %%
# Split the data into training and testing sets
dataset_train = np.array(df[:int(df.shape[0]*0.8)])
dataset_test = np.array(df[int(df.shape[0]*0.8):])

# %% [markdown]
# To produce the best-optimized results, we are required to scale the data.
#
# For this task, we are leveraging scikit-learn library’s MinMaxScaler() for converting the input values between 0 to 1.

# %%
# Scale the data 
scaler = MinMaxScaler(feature_range=(0,1))

dataset_train = scaler.fit_transform(dataset_train)
dataset_test = scaler.transform(dataset_test)

# %% [markdown]
# We will create the helper function with 50 timesteps. In other words, for the features(x) we'll append the last 50 prices, and for the label(y) we'll append the next price.
#
# After that we will convert it into a NumPy array.

# %%
# Create the function that will help us to create the datasets
def create_dataset(df):
    x = []
    y = []
    for i in range(50, df.shape[0]):
        x.append(df[i-50:i, 0]) 
        y.append(df[i, 0]) 
    x = np.array(x) 
    y = np.array(y)
    return x,y

# %%
# Create the training and testing data by calling our function for each one
x_train, y_train = create_dataset(dataset_train)
x_test, y_test = create_dataset(dataset_test)

# %%
# Reshape the data to make it a 3D array in order to use it in LSTM Layer
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# ## Building Model

# %% [markdown]
# For the LSTM layer, we add 96 units that represent the dimensionality of the output space.
#
# The return_sequences parameter is set to True for returning the last output in output.
#
# For the Dropout layers, we specify the percentage of layers is 20% that should be dropped.
#
# The next step is to add the Dense layer.

# %%
model = Sequential()
model.add(LSTM(units=96, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=96, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=96, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=96))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# %%
# Summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 96)            37632
#
#  dropout (Dropout)           (None, 50, 96)            0
#
#  lstm_1 (LSTM)               (None, 50, 96)            74112
#
#  dropout_1 (Dropout)         (None, 50, 96)            0
#
#  lstm_2 (LSTM)               (None, 50, 96)            74112
#
#  dropout_2 (Dropout)         (None, 50, 96)            0
#
#  lstm_3 (LSTM)               (None, 96)                74112
#
#  dropout_3 (Dropout)         (None, 96)                0
#
#  dense (Dense)               (None, 1)                 97
#
# =================================================================
# Total params: 260065 (1015.88 KB)
# Trainable params: 260065 (1015.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Reshape the feature for the LSTM layer 
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1)) # for expecting 3 dimentions, not 2
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# We will compile the model with the help of adam optimizer.
#
# The error is computed using mean_squared_error

# %%
# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# ## Training Model

# %% [markdown]
# With our model and data constructed, we can now train the model.

# %%
# Define modifiable training hyperparameters
epochs = 40
batch_size = 64 

# Save the model and start the training
model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size)
model.save('stock_prediction')
# Out:
# Epoch 1/40
# 61/61 [==============================] - 27s 295ms/step - loss: 0.0049
# Epoch 2/40
# 61/61 [==============================] - 19s 306ms/step - loss: 0.0012
# Epoch 3/40
# 61/61 [==============================] - 19s 305ms/step - loss: 0.0012
# Epoch 4/40
# 61/61 [==============================] - 19s 306ms/step - loss: 9.6310e-04
# Epoch 5/40
# 61/61 [==============================] - 18s 300ms/step - loss: 0.0010
# Epoch 6/40
# 61/61 [==============================] - 18s 300ms/step - loss: 8.8266e-04
# Epoch 7/40
# 61/61 [==============================] - 18s 297ms/step - loss: 0.0012
# Epoch 8/40
# 61/61 [==============================] - 19s 306ms/step - loss: 7.8077e-04
# Epoch 9/40
# 61/61 [==============================] - 19s 307ms/step - loss: 7.3696e-04
# Epoch 10/40
# 61/61 [==============================] - 19s 307ms/step - loss: 8.0560e-04
# Epoch 11/40
# 61/61 [==============================] - 19s 305ms/step - loss: 7.0034e-04
# Epoch 12/40
# 61/61 [==============================] - 18s 303ms/step - loss: 8.4862e-04
# Epoch 13/40
# 61/61 [==============================] - 18s 300ms/step - loss: 6.8885e-04
# Epoch 14/40
# 61/61 [==============================] - 18s 301ms/step - loss: 8.8549e-04
# Epoch 15/40
# 61/61 [==============================] - 19s 305ms/step - loss: 6.7200e-04
# Epoch 16/40
# 61/61 [==============================] - 18s 302ms/step - loss: 6.3448e-04
# Epoch 17/40
# 61/61 [==============================] - 18s 302ms/step - loss: 7.8149e-04
# Epoch 18/40
# 61/61 [==============================] - 19s 306ms/step - loss: 6.2163e-04
# Epoch 19/40
# 61/61 [==============================] - 19s 305ms/step - loss: 5.9587e-04
# Epoch 20/40
# 61/61 [==============================] - 18s 302ms/step - loss: 5.6419e-04
# Epoch 21/40
# 61/61 [==============================] - 19s 307ms/step - loss: 5.6018e-04
# Epoch 22/40
# 61/61 [==============================] - 19s 306ms/step - loss: 5.0779e-04
# Epoch 23/40
# 61/61 [==============================] - 19s 307ms/step - loss: 5.6357e-04
# Epoch 24/40
# 61/61 [==============================] - 18s 301ms/step - loss: 4.9797e-04
# Epoch 25/40
# 61/61 [==============================] - 18s 303ms/step - loss: 7.1479e-04
# Epoch 26/40
# 61/61 [==============================] - 18s 302ms/step - loss: 4.9762e-04
# Epoch 27/40
# 61/61 [==============================] - 18s 302ms/step - loss: 6.3623e-04
# Epoch 28/40
# 61/61 [==============================] - 19s 306ms/step - loss: 4.8729e-04
# Epoch 29/40
# 61/61 [==============================] - 18s 303ms/step - loss: 5.5823e-04
# Epoch 30/40
# 61/61 [==============================] - 19s 309ms/step - loss: 4.9888e-04
# Epoch 31/40
# 61/61 [==============================] - 19s 311ms/step - loss: 4.7662e-04
# Epoch 32/40
# 61/61 [==============================] - 19s 306ms/step - loss: 4.3933e-04
# Epoch 33/40
# 61/61 [==============================] - 19s 305ms/step - loss: 5.0993e-04
# Epoch 34/40
# 61/61 [==============================] - 19s 303ms/step - loss: 4.3948e-04
# Epoch 35/40
# 61/61 [==============================] - 18s 301ms/step - loss: 5.4062e-04
# Epoch 36/40
# 61/61 [==============================] - 19s 304ms/step - loss: 4.8606e-04
# Epoch 37/40
# 61/61 [==============================] - 18s 302ms/step - loss: 6.4224e-04
# Epoch 38/40
# 61/61 [==============================] - 18s 303ms/step - loss: 4.3940e-04
# Epoch 39/40
# 61/61 [==============================] - 20s 331ms/step - loss: 4.3001e-04
# Epoch 40/40
# 61/61 [==============================] - 19s 315ms/step - loss: 6.2179e-04
# INFO:tensorflow:Assets written to: stock_prediction\assets
# INFO:tensorflow:Assets written to: stock_prediction\assets

# %%
# Load the model
model = load_model('stock_prediction')

# %% [markdown]
# # Prediction Model

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 29/29 [==============================] - 5s 121ms/step

# %% [markdown]
# # Plotting Results

# %%
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(20,15))
ax.set_facecolor('#000035')
ax.plot(y_test_scaled, color='blue', linewidth=2, label='Original price')
plt.plot(predictions, color='yellow', linewidth=2.5, label='Predicted price')
plt.title('Netflix Stock Price Prediction')
plt.legend();

# %% [markdown]
# ## Thankyou
